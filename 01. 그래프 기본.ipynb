# %% [markdown]
# # Matplotlib
# 다양한 형태의 그래프를 통해서 데이터 시각화를 할 수 있는 라이브러리

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. 그래프 기본

# %%
x = [1, 2, 3]
y = [2, 4, 8]
plt.plot(x, y)

# %%
print(plt.plot(x, y))
# Out:
# [<matplotlib.lines.Line2D object at 0x7fc39014f220>]

# %%
plt.plot(x, y)
plt.show() # 그래프 밑에 출력 없앰

# %% [markdown]
# ## Title 설정

# %%
plt.plot(x, y)
plt.title('Line Graph')
# Out:
# Text(0.5, 1.0, 'Line Graph')

# %%
plt.plot(x, y)
plt.title('꺾은선 그래프')
# Out:
# Text(0.5, 1.0, '꺾은선 그래프')
# /Users/jinoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 44734 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/jinoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 51008 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/jinoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 49440 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/jinoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 44536 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/jinoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 47000 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/jinoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 54532 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/jinoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 44734 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/jinoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 51008 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/jinoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 49440 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/jinoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 44536 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/jinoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 47000 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/jinoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 54532 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ## 한글 폰트 설정

# %%
import matplotlib
matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac
# matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows
matplotlib.rcParams['font.size'] = 15 # 글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용 시, 마이너스 글자가 깨지는 현상을 해결

# %%
import matplotlib.font_manager as fm
fm.fontManager.ttflist # 사용 가능한 폰트 확안
[f.name for f in fm.fontManager.ttflist] # 사용 가능한 폰트 이름만 가져옴
# Out:
# ['STIXGeneral',
#  'DejaVu Serif',
#  'STIXGeneral',
#  'cmr10',
#  'STIXSizeThreeSym',
#  'cmmi10',
#  'STIXSizeFiveSym',
#  'STIXGeneral',
#  'STIXSizeFourSym',
#  'STIXNonUnicode',
#  'DejaVu Serif',
#  'STIXGeneral',
#  'cmss10',
#  'DejaVu Sans',
#  'DejaVu Serif',
#  'cmex10',
#  'STIXSizeFourSym',
#  'DejaVu Sans Mono',
#  'STIXSizeThreeSym',
#  'STIXSizeOneSym',
#  'DejaVu Sans Mono',
#  'DejaVu Serif Display',
#  'cmb10',
#  'STIXSizeOneSym',
#  'DejaVu Sans',
#  'STIXSizeTwoSym',
#  'DejaVu Sans Mono',
#  'cmsy10',
#  'STIXSizeTwoSym',
#  'DejaVu Sans Display',
#  'STIXNonUnicode',
#  'cmtt10',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'STIXNonUnicode',
#  'DejaVu Sans Mono',
#  'Trebuchet MS',
#  'Gill Sans',
#  'Noto Sans Lepcha',
#  'Noto Sans Miao',
#  'Noto Sans Myanmar',
#  'Geeza Pro',
#  'Arial Hebrew',
#  'Silom',
#  'Noto Sans Kaithi',
#  'Noto Sans Inscriptional Pahlavi',
#  'Kohinoor Devanagari',
#  'STIXNonUnicode',
#  'Noto Sans Tagalog',
#  'Noto Serif Balinese',
#  'Arial Narrow',
#  'STIXSizeThreeSym',
#  'Herculanum',
#  'Noto Sans Javanese',
#  'Noto Sans Nabataean',
#  'Hiragino Sans',
#  'Al Nile',
#  'Mishafi',
#  'Hiragino Sans',
#  'Noto Sans Armenian',
#  'Cochin',
#  'Krungthep',
#  'Noto Sans Buhid',
#  'STIXSizeThreeSym',
#  'Arial',
#  'Times',
#  'STIXIntegralsD',
#  'Chalkboard',
#  'Noto Sans Carian',
#  'Noto Sans Syriac',
#  'Didot',
#  'Noto Sans Hanifi Rohingya',
#  'Noto Sans Cuneiform',
#  'STIXGeneral',
#  'Noto Sans Old Turkic',
#  'Bangla MN',
#  'Palatino',
#  'Phosphate',
#  'Arial Rounded MT Bold',
#  'Noto Sans Osage',
#  'Noto Sans Coptic',
#  'Futura',
#  'Kohinoor Gujarati',
#  'Iowan Old Style',
#  'Noto Sans Warang Citi',
#  'Impact',
#  'Noto Sans Pau Cin Hau',
#  'Arial',
#  'Menlo',
#  'Apple Braille',
#  'Papyrus',
#  'Noto Sans Kayah Li',
#  'Arial Black',
#  '.SF Arabic',
#  'Noto Sans Cham',
#  'Noto Sans Modi',
#  'STIXGeneral',
#  'STIXSizeFourSym',
#  'STIXGeneral',
#  'STIXGeneral',
#  'Luminari',
#  'Galvji',
#  '.SF NS Rounded',
#  'Baghdad',
#  'PT Sans',
#  'Thonburi',
#  'STIXNonUnicode',
#  'Hiragino Sans',
#  'Noto Sans Brahmi',
#  'Big Caslon',
#  'Noto Sans Tai Viet',
#  'Noto Sans Gunjala Gondi',
#  '.SF NS Mono',
#  'Noto Sans Yi',
#  'STIXSizeFourSym',
#  'PingFang HK',
#  'Monaco',
#  'Georgia',
#  'AppleGothic',
#  'Noto Sans Sundanese',
#  'Bodoni 72 Smallcaps',
#  'Noto Sans Lydian',
#  'Courier New',
#  'Devanagari MT',
#  'Times New Roman',
#  'Bodoni 72',
#  'Courier',
#  'Noto Sans Sora Sompeng',
#  'Nadeem',
#  'Noto Sans Old South Arabian',
#  'Noto Sans Inscriptional Parthian',
#  'PT Mono',
#  'Verdana',
#  'STIXVariants',
#  'STIXIntegralsUpD',
#  'Apple Symbols',
#  'Noto Sans Tifinagh',
#  'Apple SD Gothic Neo',
#  'Diwan Thuluth',
#  'Verdana',
#  'STIXIntegralsUpSm',
#  'Noto Sans Khudawadi',
#  'Plantagenet Cherokee',
#  'Noto Sans NKo',
#  'Kohinoor Bangla',
#  'Georgia',
#  'STIXNonUnicode',
#  '.SF Compact',
#  'Telugu MN',
#  'Bodoni 72 Oldstyle',
#  '.Keyboard',
#  'Sukhumvit Set',
#  'Noto Sans Newa',
#  'Trebuchet MS',
#  'Noto Sans Old Permic',
#  'Noto Sans Multani',
#  'Academy Engraved LET',
#  'Farisi',
#  'Hiragino Sans',
#  'Noto Sans Tai Le',
#  'Apple Braille',
#  'Muna',
#  'Marker Felt',
#  'Andale Mono',
#  'Noto Sans Lisu',
#  'Noto Serif Yezidi',
#  'New Peninim MT',
#  'Trebuchet MS',
#  'Sathu',
#  'AppleMyungjo',
#  'Noto Sans Limbu',
#  'Noto Sans Caucasian Albanian',
#  'Noto Sans Duployan',
#  'Noto Sans Samaritan',
#  'Kailasa',
#  'Myanmar Sangam MN',
#  'Noto Sans Meroitic',
#  'Malayalam MN',
#  'Lao MN',
#  'Noto Sans Bhaiksuki',
#  'Euphemia UCAS',
#  'STIXIntegralsD',
#  'Apple Braille',
#  'Sinhala MN',
#  'Superclarendon',
#  'Sinhala Sangam MN',
#  'Noto Sans Batak',
#  'Bodoni Ornaments',
#  'Noto Sans Cypriot',
#  'Noto Sans Kharoshthi',
#  'Noto Sans Wancho',
#  'Lao Sangam MN',
#  'DecoType Naskh',
#  'Noto Sans Takri',
#  'Noto Sans Old North Arabian',
#  'PT Serif',
#  'Noto Sans Adlam',
#  'Savoye LET',
#  'Noto Sans Vai',
#  'Diwan Kufi',
#  'Avenir Next',
#  'Times New Roman',
#  'Mishafi Gold',
#  'Brush Script MT',
#  'KufiStandardGK',
#  'Noto Sans Tirhuta',
#  'Ayuthaya',
#  'Noto Sans Hanunoo',
#  'Farah',
#  'Noto Sans Imperial Aramaic',
#  'Zapf Dingbats',
#  'Georgia',
#  'Chalkboard SE',
#  'Wingdings',
#  'Waseem',
#  'Optima',
#  'Noto Sans Linear A',
#  'Kohinoor Telugu',
#  'Hoefler Text',
#  'Malayalam Sangam MN',
#  'Noto Sans Manichaean',
#  'Hiragino Sans GB',
#  'Wingdings 2',
#  'Noto Sans Mro',
#  'Noto Sans Chakma',
#  'Hiragino Sans',
#  'Gurmukhi Sangam MN',
#  'Noto Sans Meetei Mayek',
#  'Verdana',
#  'Times New Roman',
#  '.SF Compact Rounded',
#  'Noto Sans Masaram Gondi',
#  'Courier New',
#  'Hiragino Sans',
#  'Arial',
#  'STIXIntegralsSm',
#  'Noto Sans Egyptian Hieroglyphs',
#  'STIXSizeFiveSym',
#  'Noto Sans Glagolitic',
#  'Bradley Hand',
#  'Noteworthy',
#  'STIXIntegralsUp',
#  'System Font',
#  'Khmer MN',
#  'InaiMathi',
#  'Shree Devanagari 714',
#  'STIXIntegralsUp',
#  'Noto Sans Psalter Pahlavi',
#  'Hiragino Sans',
#  '.SF Compact',
#  'Gujarati Sangam MN',
#  'Helvetica',
#  'Noto Sans Mende Kikakui',
#  'Apple Braille',
#  'Noto Sans Pahawh Hmong',
#  'Times New Roman',
#  'Noto Serif Ahom',
#  'Bangla Sangam MN',
#  '.SF NS Mono',
#  'Gujarati MT',
#  'Hoefler Text',
#  'Hiragino Sans',
#  'Noto Sans Thaana',
#  'Noto Sans Rejang',
#  'Noto Sans Avestan',
#  'SignPainter',
#  'Heiti TC',
#  'Al Tarikh',
#  'Geneva',
#  'STIXNonUnicode',
#  'Hiragino Sans',
#  'Kokonor',
#  'Noto Sans Lycian',
#  'Noto Sans Kannada',
#  'Kefa',
#  'Arial Narrow',
#  'Myanmar MN',
#  'Oriya Sangam MN',
#  'Corsiva Hebrew',
#  'Trebuchet MS',
#  'Apple Chancery',
#  'Noto Sans Syloti Nagri',
#  'Marion',
#  'Noto Sans Mandaic',
#  'Georgia',
#  'Tamil MN',
#  'Telugu Sangam MN',
#  'Symbol',
#  'DIN Condensed',
#  'Courier New',
#  'Mshtakan',
#  'Lucida Grande',
#  '.Aqua Kana',
#  'Skia',
#  'Webdings',
#  'Devanagari Sangam MN',
#  'Noto Sans Mongolian',
#  'Zapfino',
#  'STIXSizeTwoSym',
#  'Noto Sans Bassa Vah',
#  'STIXIntegralsUpSm',
#  'Kannada Sangam MN',
#  'Rockwell',
#  'Noto Sans Tai Tham',
#  'Avenir Next Condensed',
#  'Noto Serif Myanmar',
#  'Heiti TC',
#  'Arial',
#  'Noto Sans Marchen',
#  'Avenir',
#  'Comic Sans MS',
#  'DIN Alternate',
#  'Noto Sans Siddham',
#  'Noto Sans Phoenician',
#  'Copperplate',
#  'Noto Sans Tagbanwa',
#  'Noto Sans Bamum',
#  'Verdana',
#  'American Typewriter',
#  'Gurmukhi MN',
#  'Noto Sans Old Hungarian',
#  'Noto Sans Khojki',
#  'Noto Sans Gothic',
#  'Arial Unicode MS',
#  'Noto Sans Ugaritic',
#  'Noto Nastaliq Urdu',
#  'Hiragino Mincho ProN',
#  'Noto Sans Osmanya',
#  'STIXIntegralsSm',
#  'Al Bayan',
#  'Hiragino Maru Gothic Pro',
#  'Athelas',
#  'Microsoft Sans Serif',
#  '.New York',
#  'Noto Sans Buginese',
#  'Snell Roundhand',
#  'Mukta Mahee',
#  'Noto Sans Mahajani',
#  'Noto Sans Linear B',
#  'Gurmukhi MT',
#  'Noto Sans Hatran',
#  '.New York',
#  'Arial Narrow',
#  'STIXSizeOneSym',
#  'Damascus',
#  'Noto Sans Old Italic',
#  'Noto Sans Old Persian',
#  'Noto Sans Palmyrene',
#  'Party LET',
#  'Arial Unicode MS',
#  'Trattatello',
#  'Wingdings 3',
#  'Noto Sans Saurashtra',
#  'Apple Braille',
#  'Kannada MN',
#  'Tahoma',
#  'Noto Sans Ol Chiki',
#  'PT Serif Caption',
#  'Khmer Sangam MN',
#  'Tamil Sangam MN',
#  'Helvetica Neue',
#  'Comic Sans MS',
#  'Baskerville',
#  'Oriya MN',
#  'Beirut',
#  'Hiragino Sans',
#  'STIXSizeTwoSym',
#  'System Font',
#  'Raanana',
#  'Noto Sans PhagsPa',
#  'Songti SC',
#  'Chalkduster',
#  'Noto Sans Sharada',
#  'STIXIntegralsUpD',
#  'ITF Devanagari',
#  'Tahoma',
#  'Sana',
#  'Charter',
#  'Seravek',
#  'Noto Sans Oriya',
#  'Arial Narrow',
#  'Noto Sans New Tai Lue',
#  'STIXSizeOneSym',
#  'Noto Sans Elbasan',
#  'Courier New',
#  'STIXVariants']

# %%
plt.plot(x, y)
plt.title('꺾은선 그래프')
# Out:
# Text(0.5, 1.0, '꺾은선 그래프')

# %%
plt.plot([-1, 0, 1], [-5, -1, -2])
